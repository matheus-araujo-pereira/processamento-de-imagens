# %% [markdown]
# # Código baseado no Capítulo 2 do Livro do Gonzales

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.io as io

# %%
mega_man = io.imread('mega_man.jpg')

# %%
mega_man.dtype
# Out:
# dtype('uint8')

# %%
2**3000
# Out:
# ...

# %% [markdown]
# ## Obtendo informações da imagem do Mega Man

# %%
mega_man.shape
# Out:
# (500, 500, 3)

# %%
mega_man[0:5,0:5]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# ### Imagem do canto superior esquerdo

# %%
plt.imshow(mega_man[:5,:5], cmap='gray', vmin=0, vmax=255)

# %%
plt.imshow(mega_man[:5,:5]*4, cmap='gray', vmin=0, vmax=255)
